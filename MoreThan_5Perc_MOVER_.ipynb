# %%
from time import sleep
from datetime import datetime
from tradingview_screener import Query, col
# Set display options to prevent column wrapping
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0) # Adjust as needed, 0 will use the full available width

from colorama import Fore, Back, Style     
import urllib.parse
 


from collections import defaultdict
from tvDatafeed import TvDatafeed,Interval
tv = TvDatafeed()
support_line = defaultdict(float)
resistance_line = defaultdict(float)
import csv

# def add_string_to_csv(filename, symbol):
#     """
#     Adds a string to a CSV file, writing each character as a separate field in a new row.

#     Args:
#         filename (str): The name of the CSV file to write to.
#         string_data (str): The string to add to the CSV file.
#     """
#     with open(filename, 'a', newline='\n') as csvfile:
#         current_time = datetime.now().strftime('%H:%M:%S')
#         writer = csv.writer(csvfile)
#         # strData = f":Alert for {symbol} ::  'https://in.tradingview.com/chart/N8zfIJVK/?symbol={symbol}' : Support Line: {support_line[symbol]}, Resistance Line: {resistance_line[symbol]}"
#         writer.writerow([current_time,symbol,f'https://in.tradingview.com/chart/N8zfIJVK/?symbol={symbol}',])

# def write_to_csv(symbol, minute_data,length): 
#     add_string_to_csv('SCREENER ALERTS_HIGH_VALUE'+str(current_DATE)+'.csv',symbol)
#     return True
   


master_combined =  pd.DataFrame()

import pandas as pd
import os

def append_df_to_csv(df, csv_path):
    print(df.head())
    if not os.path.exists(csv_path):
        df.to_csv(csv_path, mode='a', header=True, index=False)
    else:
        df.to_csv(csv_path, mode='a', header=False, index=False)


HIGH_VALUE = 20000000.00
VOLUME_MULTIPLIER =  5.0
writeHeader=True



# tvQuery = Query().set_markets('india') 
# _,dfNew = (tvQuery
#  .select('name', 'close', 'volume', 'volume|1','Value.Traded|1','average_volume_10d_calc','average_volume_10d_calc|1')
# .where(        
#         col('Value.Traded|1')> HIGH_VALUE 
#     )
# # .order_by('relative_volume_intraday|5', ascending=False)
# .order_by('volume|1', ascending=False).get_scanner_data()) 

#     query = Query().set_markets('india')
    
    # Select the columns we want to display
query = Query().select(
    'name',                    # Stock name
    'change_from_open',
    'close',                   # Current price
    'volume'   
               
    
).where(
    col('is_primary') == True,
    col('typespecs').has('common'),
    col('type') == 'stock',
    col('exchange') == 'NSE',
    col('close').between(2, 10000),
    col('active_symbol') == True,
    col('change_from_open') >= 5,

).order_by(
    'volume', ascending=False
).limit(200).set_markets('india').set_property(
    'preset', 'all_stocks'
).set_property(
    'symbols', {'query': {'types': ['stock', 'fund', 'dr']}}
)
# Execute the query
_, dfNew = query.get_scanner_data()

if not dfNew.empty :
    current_time = datetime.now().strftime('%H:%M:%S')
    
    current_DATE = datetime.now().strftime('%d_%m_%y')

    # dfNew.insert(2, 'baseURL', "https://in.tradingview.com/chart/N8zfIJVK/?symbol="+str(dfNew['ticker'])+"") 
    # Insert the current time as a new column at the beginning of the DataFrame
    dfNew.insert(3, 'URL',"")  
    dfNew['encodedTicker'] = dfNew['ticker'].apply(urllib.parse.quote)
    dfNew['URL'] = "https://in.tradingview.com/chart/N8zfIJVK/?symbol="+dfNew['encodedTicker']+" "
 
    # Filter rows where col1 is 3 times col2
    #  
    if not dfNew.empty : 
        append_df_to_csv(dfNew, 'MoreThan_5Perc_MOVER'+str(current_DATE)+'.csv')
        print(f"=="*30)
        # print(filtered_df)
        writeHeader=False 
        print(dfNew)
# Out:
# you are using nologin method, data you access may be limited
#           ticker       name  change_from_open                                                URL   close     volume    encodedTicker
# 0    NSE:OLAELEC    OLAELEC          7.158590  https://in.tradingview.com/chart/N8zfIJVK/?sym...   48.65  234142014    NSE%3AOLAELEC
# 1       NSE:PGEL       PGEL          5.506200  https://in.tradingview.com/chart/N8zfIJVK/?sym...  570.05    6281965       NSE%3APGEL
# 2      NSE:DENTA      DENTA          5.341772  https://in.tradingview.com/chart/N8zfIJVK/?sym...  416.10    3199941      NSE%3ADENTA
# 3       NSE:DYCL       DYCL         10.782341  https://in.tradingview.com/chart/N8zfIJVK/?sym...  468.00    2449643       NSE%3ADYCL
# 4  NSE:LEMONTREE  LEMONTREE          5.223529  https://in.tradingview.com/chart/N8zfIJVK/?sym...  156.52    2357656  NSE%3ALEMONTREE
# ============================================================
#             ticker        name  change_from_open                                                URL    close     volume     encodedTicker
# 0      NSE:OLAELEC     OLAELEC          7.158590  https://in.tradingview.com/chart/N8zfIJVK/?sym...    48.65  234142014     NSE%3AOLAELEC
# 1         NSE:PGEL        PGEL          5.506200  https://in.tradingview.com/chart/N8zfIJVK/?sym...   570.05    6281965        NSE%3APGEL
# 2        NSE:DENTA       DENTA          5.341772  https://in.tradingview.com/chart/N8zfIJVK/?sym...   416.10    3199941       NSE%3ADENTA
# 3         NSE:DYCL        DYCL         10.782341  https://in.tradingview.com/chart/N8zfIJVK/?sym...   468.00    2449643        NSE%3ADYCL
# 4    NSE:LEMONTREE   LEMONTREE          5.223529  https://in.tradingview.com/chart/N8zfIJVK/?sym...   156.52    2357656   NSE%3ALEMONTREE
# 5        NSE:YATRA       YATRA          6.911565  https://in.tradingview.com/chart/N8zfIJVK/?sym...   157.16    2208076       NSE%3AYATRA
# 6      NSE:SADBHAV     SADBHAV          7.442490  https://in.tradingview.com/chart/N8zfIJVK/?sym...    15.88    1943161     NSE%3ASADBHAV
# 7         NSE:WCIL        WCIL          7.028754  https://in.tradingview.com/chart/N8zfIJVK/?sym...   127.30    1577028        NSE%3AWCIL
# 8       NSE:MAHEPC      MAHEPC         12.658228  https://in.tradingview.com/chart/N8zfIJVK/?sym...   178.00    1521544      NSE%3AMAHEPC
# 9    NSE:SERVOTECH   SERVOTECH          5.478909  https://in.tradingview.com/chart/N8zfIJVK/?sym...   133.03     935097   NSE%3ASERVOTECH
# 10         NSE:TRU         TRU          8.631579  https://in.tradingview.com/chart/N8zfIJVK/?sym...    10.32     857951         NSE%3ATRU
# 11  NSE:RAYMONDLSL  RAYMONDLSL          5.262718  https://in.tradingview.com/chart/N8zfIJVK/?sym...  1258.10     650540  NSE%3ARAYMONDLSL
# 12     NSE:RISHABH     RISHABH          5.452726  https://in.tradingview.com/chart/N8zfIJVK/?sym...   421.60     541063     NSE%3ARISHABH
# 13  NSE:SHREDIGCEM  SHREDIGCEM          5.514072  https://in.tradingview.com/chart/N8zfIJVK/?sym...    91.85     459305  NSE%3ASHREDIGCEM
# 14     NSE:NACLIND     NACLIND          8.649789  https://in.tradingview.com/chart/N8zfIJVK/?sym...   257.50     413061     NSE%3ANACLIND
# 15     NSE:PROTEAN     PROTEAN          5.515095  https://in.tradingview.com/chart/N8zfIJVK/?sym...   796.85     270772     NSE%3APROTEAN
# 16    NSE:ZUARIIND    ZUARIIND          7.550393  https://in.tradingview.com/chart/N8zfIJVK/?sym...   314.80     179757    NSE%3AZUARIIND
# 17    NSE:GOODLUCK    GOODLUCK          6.139303  https://in.tradingview.com/chart/N8zfIJVK/?sym...  1066.70     140942    NSE%3AGOODLUCK
# 18         NSE:WSI         WSI          8.562500  https://in.tradingview.com/chart/N8zfIJVK/?sym...    86.85     128513         NSE%3AWSI
# 19      NSE:KAYTEX      KAYTEX          6.125971  https://in.tradingview.com/chart/N8zfIJVK/?sym...   123.00     116800      NSE%3AKAYTEX
# 20   NSE:MANAKCOAT   MANAKCOAT          5.140507  https://in.tradingview.com/chart/N8zfIJVK/?sym...   153.40     116132   NSE%3AMANAKCOAT
# 21  NSE:SIMPLEXINF  SIMPLEXINF          7.171664  https://in.tradingview.com/chart/N8zfIJVK/?sym...   305.60     106700  NSE%3ASIMPLEXINF
# 22       NSE:SILGO       SILGO          8.019802  https://in.tradingview.com/chart/N8zfIJVK/?sym...    65.46      91190       NSE%3ASILGO
# 23    NSE:GCHOTELS    GCHOTELS         11.055276  https://in.tradingview.com/chart/N8zfIJVK/?sym...   232.05      75600    NSE%3AGCHOTELS
# 24    NSE:SAMBHAAV    SAMBHAAV          5.198777  https://in.tradingview.com/chart/N8zfIJVK/?sym...     6.88      55364    NSE%3ASAMBHAAV
# 25  NSE:ARROWGREEN  ARROWGREEN          5.815189  https://in.tradingview.com/chart/N8zfIJVK/?sym...   597.75      40753  NSE%3AARROWGREEN
# 26  NSE:VARDHACRLC  VARDHACRLC          5.431818  https://in.tradingview.com/chart/N8zfIJVK/?sym...    46.39      35465  NSE%3AVARDHACRLC
# 27     NSE:LATTEYS     LATTEYS          7.563452  https://in.tradingview.com/chart/N8zfIJVK/?sym...    21.19      31520     NSE%3ALATTEYS
# 28  NSE:OSELDEVICE  OSELDEVICE          6.221591  https://in.tradingview.com/chart/N8zfIJVK/?sym...   560.85      30400  NSE%3AOSELDEVICE
# 29       NSE:ARHAM       ARHAM         14.743590  https://in.tradingview.com/chart/N8zfIJVK/?sym...    89.50      22000       NSE%3AARHAM
# 30   NSE:FOSECOIND   FOSECOIND          6.422198  https://in.tradingview.com/chart/N8zfIJVK/?sym...  5427.00      15036   NSE%3AFOSECOIND
# 31  NSE:HITECHCORP  HITECHCORP          5.289737  https://in.tradingview.com/chart/N8zfIJVK/?sym...   206.41       9001  NSE%3AHITECHCORP
# 32       NSE:PKTEA       PKTEA          5.181965  https://in.tradingview.com/chart/N8zfIJVK/?sym...   750.00       4007       NSE%3APKTEA
# 33     NSE:SMSLIFE     SMSLIFE          6.588066  https://in.tradingview.com/chart/N8zfIJVK/?sym...  1184.30       3938     NSE%3ASMSLIFE
# 34        NSE:KORE        KORE         10.476190  https://in.tradingview.com/chart/N8zfIJVK/?sym...   121.80       3500        NSE%3AKORE
# 35   NSE:KAUSHALYA   KAUSHALYA         15.749471  https://in.tradingview.com/chart/N8zfIJVK/?sym...  1012.75       2876   NSE%3AKAUSHALYA
# 36        NSE:NIBL        NIBL          6.475410  https://in.tradingview.com/chart/N8zfIJVK/?sym...    25.98       2670        NSE%3ANIBL
# 37         NSE:LAL         LAL          6.627102  https://in.tradingview.com/chart/N8zfIJVK/?sym...    10.78       1186         NSE%3ALAL
# 38   NSE:HYBRIDFIN   HYBRIDFIN          6.543385  https://in.tradingview.com/chart/N8zfIJVK/?sym...    14.98       1010   NSE%3AHYBRIDFIN
# 39         NSE:CTE         CTE          6.097561  https://in.tradingview.com/chart/N8zfIJVK/?sym...    43.50        927         NSE%3ACTE
# 40  NSE:REGENCERAM  REGENCERAM          8.346012  https://in.tradingview.com/chart/N8zfIJVK/?sym...    49.85        511  NSE%3AREGENCERAM
# 41  NSE:NIRAJISPAT  NIRAJISPAT         10.521486  https://in.tradingview.com/chart/N8zfIJVK/?sym...   361.35         12  NSE%3ANIRAJISPAT
