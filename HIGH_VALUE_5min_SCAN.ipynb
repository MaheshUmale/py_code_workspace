# %%
from time import sleep
from datetime import datetime
from tradingview_screener import Query, col
# Set display options to prevent column wrapping
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 0) # Adjust as needed, 0 will use the full available width

from colorama import Fore, Back, Style     
import urllib.parse
 


from collections import defaultdict
from tvDatafeed import TvDatafeed,Interval
tv = TvDatafeed()
support_line = defaultdict(float)
resistance_line = defaultdict(float)
import csv

# def add_string_to_csv(filename, symbol):
#     """
#     Adds a string to a CSV file, writing each character as a separate field in a new row.

#     Args:
#         filename (str): The name of the CSV file to write to.
#         string_data (str): The string to add to the CSV file.
#     """
#     with open(filename, 'a', newline='\n') as csvfile:
#         current_time = datetime.now().strftime('%H:%M:%S')
#         writer = csv.writer(csvfile)
#         # strData = f":Alert for {symbol} ::  'https://in.tradingview.com/chart/N8zfIJVK/?symbol={symbol}' : Support Line: {support_line[symbol]}, Resistance Line: {resistance_line[symbol]}"
#         writer.writerow([current_time,symbol,f'https://in.tradingview.com/chart/N8zfIJVK/?symbol={symbol}',])

# def write_to_csv(symbol, minute_data,length): 
#     add_string_to_csv('SCREENER ALERTS_HIGH_VALUE'+str(current_DATE)+'.csv',symbol)
#     return True
   


master_combined =  pd.DataFrame()

import pandas as pd
import os

def append_df_to_csv(df, csv_path):
    if not os.path.exists(csv_path):
        df.to_csv(csv_path, mode='a', header=True, index=False)
    else:
        df.to_csv(csv_path, mode='a', header=False, index=False)


HIGH_VALUE = 50000000.00
VOLUME_MULTIPLIER =  5.0
writeHeader=True
while True : 
  
 
    # tvQuery = Query().set_markets('india') 
    # _,dfNew = (tvQuery
    #  .select('name', 'close', 'volume', 'volume|1','Value.Traded|1','average_volume_10d_calc','average_volume_10d_calc|1')
    # .where(        
    #         col('Value.Traded|1')> HIGH_VALUE 
    #     )
    # # .order_by('relative_volume_intraday|5', ascending=False)
    # .order_by('volume|1', ascending=False).get_scanner_data()) 

    #     query = Query().set_markets('india')
        
        # Select the columns we want to display
    query = Query().select(
        'name',                    # Stock name
        'close',                   # Current price
        'volume|5',                # 1-minute volume
        'Value.Traded|5',          # 1-minute traded value
        'average_volume_10d_calc', # Average volume (10 days)
        'average_volume_10d_calc|5' # Average 1-minute volume (10 days)
    ).where(
        col('is_primary') == True,
        col('typespecs').has('common'),
        col('type') == 'stock',
        col('exchange') == 'NSE',
        col('close').between(2, 10000),
        col('active_symbol') == True,
        col('Value.Traded|5') > HIGH_VALUE,

    ).order_by(
        'volume|1', ascending=False
    ).limit(100).set_markets('india').set_property(
        'preset', 'all_stocks'
    ).set_property(
        'symbols', {'query': {'types': ['stock', 'fund', 'dr']}}
    )
    # Execute the query
    _, dfNew = query.get_scanner_data()
   
    if not dfNew.empty :
        current_time = datetime.now().strftime('%H:%M:%S')
        
        current_DATE = datetime.now().strftime('%d_%m_%y')

        # dfNew.insert(2, 'baseURL', "https://in.tradingview.com/chart/N8zfIJVK/?symbol="+str(dfNew['ticker'])+"") 
        # Insert the current time as a new column at the beginning of the DataFrame
        dfNew.insert(3, 'URL',"")  
        dfNew['encodedTicker'] = dfNew['ticker'].apply(urllib.parse.quote)
        dfNew['URL'] = "https://in.tradingview.com/chart/N8zfIJVK/?symbol="+dfNew['encodedTicker']+" "

        dfNew.insert(0, 'current_timestamp', current_time)
        # Filter rows where col1 is 3 times col2
        # 
        dfNew['VOL_MULT_FACTOR'] = dfNew['volume|5'] / dfNew['average_volume_10d_calc|5']
        filtered_df =   dfNew[dfNew['VOL_MULT_FACTOR'] > VOLUME_MULTIPLIER] 
        
        if not filtered_df.empty : 
            append_df_to_csv(filtered_df, 'HIGH_VALUE_5MIN_VolSpike_'+str(current_DATE)+'.csv')
            print(f"=="*30)
            # print(filtered_df)
            writeHeader=False 
            print(filtered_df)
        
               
                
    sleep(120)
# Out:
# you are using nologin method, data you access may be limited
# ============================================================
#   current_timestamp      ticker    name  close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 2          13:33:21  NSE:AUBANK  AUBANK  745.9  https://in.tradingview.com/chart/N8zfIJVK/?sym...    132505     98868605.75                2740052.7                    20560.6  NSE%3AAUBANK         6.444608
# ============================================================
#   current_timestamp       ticker     name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5  encodedTicker  VOL_MULT_FACTOR
# 0          13:35:22  NSE:TFCILTD  TFCILTD  310.35  https://in.tradingview.com/chart/N8zfIJVK/?sym...    168188      52197145.8                1539338.6                    18436.2  NSE%3ATFCILTD         9.122704
# ============================================================
#   current_timestamp          ticker        name   close                                                URL   volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 0          13:39:23        NSE:IDEA        IDEA    7.12  https://in.tradingview.com/chart/N8zfIJVK/?sym...  102778915    7.328137e+08             4.594774e+08                 16362877.6        NSE%3AIDEA         6.281225
# 5          13:39:23  NSE:INDUSTOWER  INDUSTOWER  357.85  https://in.tradingview.com/chart/N8zfIJVK/?sym...    1460834    5.221751e+08             7.062258e+06                   237062.3  NSE%3AINDUSTOWER         6.162237
# ============================================================
#   current_timestamp       ticker     name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5  encodedTicker  VOL_MULT_FACTOR
# 5          13:43:24  NSE:ALLTIME  ALLTIME  322.25  https://in.tradingview.com/chart/N8zfIJVK/?sym...    169088      54480153.6                      NaN                    29162.8  NSE%3AALLTIME         5.798072
# ============================================================
#   current_timestamp     ticker   name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 6          13:47:26  NSE:AWFIS  AWFIS  570.95  https://in.tradingview.com/chart/N8zfIJVK/?sym...    107070      61131616.5                 730771.2                    11561.7   NSE%3AAWFIS         9.260749
# ============================================================
#    current_timestamp     ticker   name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 9           13:49:26  NSE:LODHA  LODHA  1269.90  https://in.tradingview.com/chart/N8zfIJVK/?sym...     76467      97151323.5                1168219.6                    11650.2   NSE%3ALODHA         6.563578
# 16          13:49:26  NSE:AWFIS  AWFIS   570.10  https://in.tradingview.com/chart/N8zfIJVK/?sym...    107242      61138664.2                 730788.3                    11578.9   NSE%3AAWFIS         9.261847
# 17          13:49:26    NSE:LTF    LTF   223.68  https://in.tradingview.com/chart/N8zfIJVK/?sym...    549455     122902094.4                5644965.1                    85280.3     NSE%3ALTF         6.442930
# ============================================================
#   current_timestamp        ticker      name  close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5   encodedTicker  VOL_MULT_FACTOR
# 3          13:53:27  NSE:GOCLCORP  GOCLCORP  388.5  https://in.tradingview.com/chart/N8zfIJVK/?sym...    201434      78257109.0                 116922.9                    20448.8  NSE%3AGOCLCORP         9.850651
# ============================================================
#   current_timestamp          ticker        name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 0          13:55:28  NSE:BECTORFOOD  BECTORFOOD  1374.9  https://in.tradingview.com/chart/N8zfIJVK/?sym...     60267      82861098.3                 109359.1                     6284.1  NSE%3ABECTORFOOD         9.590395
# ============================================================
#   current_timestamp       ticker     name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5  encodedTicker  VOL_MULT_FACTOR
# 4          13:57:29  NSE:MPHASIS  MPHASIS  2874.2  https://in.tradingview.com/chart/N8zfIJVK/?sym...     22244      63951500.0                 323734.5                     3661.4  NSE%3AMPHASIS         6.075272
# ============================================================
#   current_timestamp          ticker        name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 5          13:59:29     NSE:MPHASIS     MPHASIS  2874.50  https://in.tradingview.com/chart/N8zfIJVK/?sym...     26404      75882455.6                 324253.8                     4077.4     NSE%3AMPHASIS         6.475695
# 6          13:59:29  NSE:BANKBARODA  BANKBARODA   241.11  https://in.tradingview.com/chart/N8zfIJVK/?sym...    295682      71288930.2                5632176.0                    53410.0  NSE%3ABANKBARODA         5.536079
# ============================================================
#   current_timestamp          ticker        name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 5          14:01:30  NSE:JINDALSTEL  JINDALSTEL  997.85  https://in.tradingview.com/chart/N8zfIJVK/?sym...    503018     501735304.1                1680076.6                    54281.7  NSE%3AJINDALSTEL         9.266806
# ============================================================
#    current_timestamp          ticker        name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 5           14:03:30  NSE:JINDALSTEL  JINDALSTEL   998.2  https://in.tradingview.com/chart/N8zfIJVK/?sym...    535099     534135821.8                1683293.9                    57489.8  NSE%3AJINDALSTEL         9.307721
# 13          14:03:30     NSE:MAZDOCK     MAZDOCK  2721.0  https://in.tradingview.com/chart/N8zfIJVK/?sym...     40710     110796336.0                1337136.5                     6463.1     NSE%3AMAZDOCK         6.298835
# ============================================================
#   current_timestamp        ticker      name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5   encodedTicker  VOL_MULT_FACTOR
# 4          14:07:31  NSE:EMAMILTD  EMAMILTD  613.65  https://in.tradingview.com/chart/N8zfIJVK/?sym...    104619     64199449.35                 433483.9                    11915.6  NSE%3AEMAMILTD         8.780003
# ============================================================
#    current_timestamp         ticker       name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 11          14:09:32  NSE:POLICYBZR  POLICYBZR  1916.8  https://in.tradingview.com/chart/N8zfIJVK/?sym...     46265      88699258.0                1116161.8                     8947.5  NSE%3APOLICYBZR         5.170718
# 17          14:09:32    NSE:ACUTAAS    ACUTAAS  1423.2  https://in.tradingview.com/chart/N8zfIJVK/?sym...    103688     147651712.0                 308882.6                    12482.2    NSE%3AACUTAAS         8.306869
# 18          14:09:32   NSE:EMAMILTD   EMAMILTD   613.7  https://in.tradingview.com/chart/N8zfIJVK/?sym...    104930      64395541.0                 433519.2                    11946.7   NSE%3AEMAMILTD         8.783179
# ============================================================
#   current_timestamp      ticker    name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 3          14:13:33  NSE:MARICO  MARICO  732.85  https://in.tradingview.com/chart/N8zfIJVK/?sym...    103807      76080150.3                1593309.3                    20226.9  NSE%3AMARICO         5.132126
# ============================================================
#   current_timestamp     ticker   name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 2          14:19:35  NSE:YATRA  YATRA  153.12  https://in.tradingview.com/chart/N8zfIJVK/?sym...    365559     55992672.03               16100588.5                    53628.4   NSE%3AYATRA         6.816519
# ============================================================
#   current_timestamp         ticker       name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 1          14:21:35  NSE:KOTAKBANK  KOTAKBANK  1991.0  https://in.tradingview.com/chart/N8zfIJVK/?sym...    153712       305963736                2477454.5                    25174.2  NSE%3AKOTAKBANK         6.105934
# ============================================================
#    current_timestamp         ticker       name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 9           14:23:36  NSE:REPCOHOME  REPCOHOME   369.8  https://in.tradingview.com/chart/N8zfIJVK/?sym...    200969    7.430829e+07                 319923.8                    27817.2  NSE%3AREPCOHOME         7.224631
# 11          14:23:36  NSE:KOTAKBANK  KOTAKBANK  1990.6  https://in.tradingview.com/chart/N8zfIJVK/?sym...    156961    3.123995e+08                2477869.2                    25499.1  NSE%3AKOTAKBANK         6.155551
# ============================================================
#   current_timestamp         ticker       name  close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 0          14:25:37  NSE:REPCOHOME  REPCOHOME  369.5  https://in.tradingview.com/chart/N8zfIJVK/?sym...    201043      74285388.5                 319934.8                    27824.6  NSE%3AREPCOHOME         7.225369
# ============================================================
#    current_timestamp          ticker        name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 0           14:33:40   NSE:FINCABLES   FINCABLES   847.2  https://in.tradingview.com/chart/N8zfIJVK/?sym...    143415     121544212.5                 483102.5                    20856.8   NSE%3AFINCABLES         6.876175
# 9           14:33:40  NSE:OBEROIRLTY  OBEROIRLTY  1660.5  https://in.tradingview.com/chart/N8zfIJVK/?sym...     42077      69868858.5                 336106.9                     6061.9  NSE%3AOBEROIRLTY         6.941223
# 11          14:33:40  NSE:PHOENIXLTD  PHOENIXLTD  1584.3  https://in.tradingview.com/chart/N8zfIJVK/?sym...     72265     114489439.5                 656681.9                    10940.6  NSE%3APHOENIXLTD         6.605214
# ============================================================
#    current_timestamp          ticker        name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 2           14:43:43         NSE:RCF         RCF   158.89  https://in.tradingview.com/chart/N8zfIJVK/?sym...    507622     80701745.56                2676529.0                    74571.5         NSE%3ARCF         6.807185
# 12          14:43:43  NSE:CHAMBLFERT  CHAMBLFERT   564.95  https://in.tradingview.com/chart/N8zfIJVK/?sym...    119112     67238724.00                1436529.2                    17905.3  NSE%3ACHAMBLFERT         6.652332
# 15          14:43:43  NSE:DEEPAKFERT  DEEPAKFERT  1542.60  https://in.tradingview.com/chart/N8zfIJVK/?sym...     55053     84787125.30                 180169.1                     6187.0  NSE%3ADEEPAKFERT         8.898174
# 17          14:43:43        NSE:FACT        FACT  1015.75  https://in.tradingview.com/chart/N8zfIJVK/?sym...     79160     80406770.00                 739613.7                    10200.3        NSE%3AFACT         7.760556
# ============================================================
#   current_timestamp   ticker name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 1          14:47:45  NSE:RCF  RCF  161.15  https://in.tradingview.com/chart/N8zfIJVK/?sym...    906502     145674871.4                2774098.5                   175048.8     NSE%3ARCF         5.178567
# ============================================================
#    current_timestamp    ticker  name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 6           14:49:45   NSE:RCF   RCF   159.86  https://in.tradingview.com/chart/N8zfIJVK/?sym...   1205020    1.927911e+08                2808931.6                   204900.6     NSE%3ARCF         5.880998
# 11          14:49:45   NSE:NFL   NFL    99.30  https://in.tradingview.com/chart/N8zfIJVK/?sym...    636999    6.325400e+07                1944194.9                   107415.3     NSE%3ANFL         5.930245
# 32          14:49:45  NSE:FACT  FACT  1021.60  https://in.tradingview.com/chart/N8zfIJVK/?sym...    136139    1.391409e+08                 755751.9                    26218.0    NSE%3AFACT         5.192578
# ============================================================
#   current_timestamp      ticker    name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 4          14:51:46  NSE:NAUKRI  NAUKRI  1379.7  https://in.tradingview.com/chart/N8zfIJVK/?sym...    107745     148655776.5                2332544.2                    19238.7  NSE%3ANAUKRI          5.60043
# ============================================================
#    current_timestamp      ticker    name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 22          14:53:48  NSE:NAUKRI  NAUKRI  1381.0  https://in.tradingview.com/chart/N8zfIJVK/?sym...    115302     159220531.8                2333299.1                    19994.4  NSE%3ANAUKRI         5.766715
# ============================================================
#    current_timestamp        ticker      name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5   encodedTicker  VOL_MULT_FACTOR
# 4           15:01:50  NSE:CHOLAFIN  CHOLAFIN  1522.8  https://in.tradingview.com/chart/N8zfIJVK/?sym...     68942     104998666.0                 941868.1                    10669.1  NSE%3ACHOLAFIN         6.461838
# 20          15:01:50   NSE:HAVELLS   HAVELLS  1555.3  https://in.tradingview.com/chart/N8zfIJVK/?sym...     41051      63842515.2                 818724.4                     7432.6   NSE%3AHAVELLS         5.523101
# ============================================================
#    current_timestamp          ticker        name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 13          15:03:51    NSE:ASHOKLEY    ASHOKLEY   131.02  https://in.tradingview.com/chart/N8zfIJVK/?sym...   1096268    1.436769e+08               21928950.2                   215681.8    NSE%3AASHOKLEY         5.082803
# 31          15:03:51  NSE:GODREJPROP  GODREJPROP  2052.70  https://in.tradingview.com/chart/N8zfIJVK/?sym...     34501    7.082020e+07                 918870.3                     6293.1  NSE%3AGODREJPROP         5.482354
# 45          15:03:51    NSE:CHOLAFIN    CHOLAFIN  1522.10  https://in.tradingview.com/chart/N8zfIJVK/?sym...     75132    1.143133e+08                 942479.5                    11288.1    NSE%3ACHOLAFIN         6.655859
# 46          15:03:51     NSE:HAVELLS     HAVELLS  1553.30  https://in.tradingview.com/chart/N8zfIJVK/?sym...     45083    7.004095e+07                 819105.5                     7835.8     NSE%3AHAVELLS         5.753465
# 49          15:03:51   NSE:BRITANNIA   BRITANNIA  5541.50  https://in.tradingview.com/chart/N8zfIJVK/?sym...     22313    1.235917e+08                 370225.5                     3992.0   NSE%3ABRITANNIA         5.589429
# ============================================================
#    current_timestamp      ticker    name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5 encodedTicker  VOL_MULT_FACTOR
# 2           15:07:52   NSE:CUPID   CUPID   172.0  https://in.tradingview.com/chart/N8zfIJVK/?sym...    422949      72704933.1                4716718.4                    55066.9   NSE%3ACUPID         7.680639
# 33          15:07:52  NSE:MASTEK  MASTEK  2490.6  https://in.tradingview.com/chart/N8zfIJVK/?sym...     52484     130732395.6                  63065.8                     5579.8  NSE%3AMASTEK         9.406072
# ============================================================
#    current_timestamp          ticker        name    close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5     encodedTicker  VOL_MULT_FACTOR
# 10          15:09:53  NSE:HINDCOPPER  HINDCOPPER   238.60  https://in.tradingview.com/chart/N8zfIJVK/?sym...    226460    5.402656e+07                1612745.6                    36018.6  NSE%3AHINDCOPPER         6.287307
# 67          15:09:53       NSE:CUPID       CUPID   171.82  https://in.tradingview.com/chart/N8zfIJVK/?sym...    430111    7.390167e+07                4717742.4                    55783.1       NSE%3ACUPID         7.710418
# 69          15:09:53      NSE:MASTEK      MASTEK  2492.50  https://in.tradingview.com/chart/N8zfIJVK/?sym...     52623    1.312260e+08                  63086.7                     5593.7      NSE%3AMASTEK         9.407548
# ============================================================
#    current_timestamp         ticker       name  close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 14          15:11:53  NSE:BANKINDIA  BANKINDIA  115.5  https://in.tradingview.com/chart/N8zfIJVK/?sym...    995587     114990298.5                3879706.6                   151054.7  NSE%3ABANKINDIA         6.590904
# ============================================================
#    current_timestamp         ticker       name   close                                                URL  volume|5  Value.Traded|5  average_volume_10d_calc  average_volume_10d_calc|5    encodedTicker  VOL_MULT_FACTOR
# 45          15:13:54  NSE:BANKINDIA  BANKINDIA  115.42  https://in.tradingview.com/chart/N8zfIJVK/?sym...   1033531    1.192901e+08                3883348.8                   154849.1  NSE%3ABANKINDIA          6.67444
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 124
#     119         writeHeader=False
#     120         print(filtered_df)
# --> 124 sleep(120)
#
# KeyboardInterrupt:
